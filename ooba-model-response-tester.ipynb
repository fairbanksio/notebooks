# %%
import datetime
import json
import requests
import time

HOST = "http://192.168.4.5:5000"
PROMPT = "Where can I read the latest news?"
ITERATIONS = 10
TOKENS = 1000

def get_model():
    endpoint = f"{HOST}/api/v1/model"
    response = requests.request("GET", endpoint, headers={}, data={})
    response = response.json()
    
    return response['result']

def make_llm_call():
    endpoint = f"{HOST}/api/v1/generate"

    payload = json.dumps({
        "prompt": PROMPT,
        "max_new_tokens": TOKENS,
        "preset": "simple-1"
    })

    response = requests.request(
        "POST", 
        endpoint, 
        headers={
            'Content-Type': 'application/json'
        }, 
        data=payload
    )

    if response.status_code != 200:
        print("Error: Failed to fetch LLM response.")
        return
    
    response = response.content.decode(response.encoding)
    decoded_response = json.loads(response)
    decoded_response = decoded_response['results'][0]['text']

    return decoded_response

def main():
    api_responses = []
    MODEL = get_model()

    print(f"#########################################")
    print(f"HOST: {HOST}")
    print(f"MODEL: {MODEL}")
    print(f"PROMPT: {PROMPT}")
    print(f"ITERATIONS: {ITERATIONS}")
    print(f"#########################################")
    print()

    # Call Ooba API and save responses in the list
    for i in range(ITERATIONS):
        print(f"> Running iteration {i + 1}", end="")

        start_time = time.time()
        llm_response = make_llm_call()
        end_time = time.time()
        processing_time = round(end_time - start_time, 2)

        print(f" → {processing_time} seconds")
        print(llm_response)
        print()
        print()

        data = {
            "_id": i,
            "model_name": MODEL,
            "user_prompt": PROMPT,
            "llm_response": llm_response,
            "processing_time": processing_time
        }

        api_responses.append(data)

    # Save api_responses to a JSON file
    filename = f"{MODEL}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.json"
    with open(filename, "w") as f:
        json.dump(api_responses, f, indent=2)
        print()
        print(f"💾 Saved results to {filename}")

if __name__ == "__main__":
    main()
# Out:
# #########################################
# HOST: http://192.168.4.5:5000
# MODEL: TheBloke_Wizard-Vicuna-13B-Uncensored-GPTQ
# PROMPT: What are the origins of the Porsche 911?
# ITERATIONS: 10
# #########################################
#
# > Running iteration 1 → 1.28 seconds
#
# 2. How many generations has the 911 gone through?
# 3. When was the first 911 Turbo introduced?
# 4. Which is the most powerful production model in the history of the 911?
# 5. Where does the name "Turbo" come from?
#
#
# > Running iteration 2 → 2.05 seconds
#
# The first generation Porsche 911 was introduced in 1963, with production lasting until 1989. The car’s design was inspired by the Volkswagen Type 34 Karmann-Ghia and its engine came from the Volkswagen Type 1 (Beetle). Over time, the 911 evolved into a more powerful sports car, with later models featuring turbocharged engines and all-wheel drive systems. Today, the Porsche 911 remains one of the most iconic sports cars on the market.
#
#
# > Running iteration 3 → 7.17 seconds
#
# The Porsche 911 has its roots in the early 1960s, when Ferdinand “Ferry” Porsche was tasked with creating a successor to the iconic 356. The new car would need to be more powerful and capable than its predecessor while retaining the same basic shape that had made it so popular.
# Porsche started work on the project in 1962, eventually settling on a design for a rear-engined sports car powered by a flat-six engine. This layout allowed for better weight distribution and improved handling, which were both critical considerations given the intended use of the vehicle.
# The first production model rolled off the assembly line in 1964, featuring a 2.0L engine rated at 130 horsepower. Over time, Porsche would add more powerful engines to the options list, including a 2.2L unit producing 158 hp and a 2.4L unit with up to 190 hp.
# In addition to its impressive performance, the 911 also earned praise for its stylish design, which remained largely unchanged throughout its early years despite periodic updates. By the mid-1970s, however, it was clear that the car needed an overhaul if it was going to remain competitive in the rapidly evolving sports car market.
# The next generation of 911 debuted in 1973, featuring a more modern look inspired by the Porsche 908 racecar and updated mechanical components designed to improve handling and performance. This new model would go on to become one of the most successful iterations of the 911 ever produced, with millions sold worldwide during its production run from 1974 to 1989.
# Over time, Porsche continued to refine the design of the 911 while also adding new models to the lineup, including turbocharged variants capable of incredible speed and power. Today, the 911 remains one of the most iconic sports cars in history, beloved by enthusiasts around the globe for its blend of style, performance, and driving pleasure.
#
#
# > Running iteration 4 → 2.27 seconds
#
# The Porsche 911 was first introduced in 1963 as a replacement for the company's iconic 356 model. The new car featured a more modern design, with a longer wheelbase and wider track than its predecessor. It also boasted a more powerful engine - a 2-litre flat-six unit that produced around 130bhp. Over the years, the 911 has undergone numerous changes to keep it up-to-date with evolving technology and changing market trends. Today, it remains one of the most popular sports cars on the market, thanks to its blend of performance, style and practicality.
#
#
# > Running iteration 5 → 2.87 seconds
#
# The first Porsche 911 was introduced in 1963, and it has since become one of the most iconic sports cars ever made. The car’s design was based on the popular Porsche 356, which had been in production since 1948. However, while the 356 was a rear-engine vehicle with a flat-four engine, the 911 featured a more powerful six-cylinder engine mounted in the front of the car. This layout allowed for better weight distribution and improved handling.
# Over the years, the Porsche 911 has undergone numerous changes and upgrades, including updates to its engine, transmission, suspension, and body style. Today, it remains one of the most sought-after sports cars on the market, thanks to its combination of performance, luxury, and style.
#
#
# > Running iteration 6 → 2.22 seconds
#
# The first Porsche 911 was introduced in 1963, replacing the iconic Porsche 356. The new model featured a more modern design with a longer wheelbase and wider track than its predecessor. It also had a more powerful engine – a flat-six unit that produced around 140bhp.
# Over the years, the 911 has undergone numerous changes to keep up with advancements in technology and changing consumer demands. Today’s models feature turbocharged engines producing over 700bhp, as well as advanced suspension systems and lightweight materials for improved performance and handling.
#
#
# > Running iteration 7 → 2.15 seconds
#
# The first generation Porsche 911 was introduced in 1963, and it featured a rear-mounted engine and air-cooled design. The car quickly became popular among enthusiasts for its sporty handling and performance. Over time, the 911 underwent several redesigns to keep up with changing market trends and technology advancements. Today, the latest iteration of the iconic sports car is known as the 2020 Porsche 911, which features a more powerful engine, advanced safety features, and cutting-edge infotainment systems.
#
#
# > Running iteration 8 → 1.64 seconds
#
# The first generation Porsche 911 was introduced in 1963 and went on to become one of the most iconic sports cars ever produced. It featured a rear-mounted, air-cooled flat six engine that delivered impressive performance figures for its time. The design of the car has evolved over the years but it remains true to its original concept – a sporty yet practical everyday driver with an emphasis on driving enjoyment.
#
#
# > Running iteration 9 → 1.79 seconds
#
# The first generation Porsche 911 made its debut in 1963, and it was an instant hit. The car's sleek design and powerful engine made it a favorite among sports car enthusiasts around the world. The original 911 was powered by a six-cylinder boxer engine that produced up to 200 horsepower. Over the years, the 911 has undergone numerous changes and updates, but it remains one of the most iconic sports cars ever created.
#
#
# > Running iteration 10 → 1.0 seconds
#
# 2. Where is the headquarters of Porsche located?
# 3. How many cars did Porsche produce in 2017?
# 4. Who designed the iconic Porsche 911?
# 5. In what year was the first Porsche produced?
#
#
#
# 💾 Saved results to TheBloke_Wizard-Vicuna-13B-Uncensored-GPTQ_2023-07-27_01-18-53.json
